# %% [markdown]
# <a href="https://colab.research.google.com/github/codebuzznow-coder/Python_class1/blob/main/Operators03_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(3+3)
# Out:
# 6

# %%
"a"+"b"
# Out:
# 'ab'

# %%
4**2
# Out:
# 16

# %%
'a'**'b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_578/235926419.py in <cell line: 0>()
# ----> 1 'a'**'b'
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'str'

# %%
4.0 + 1 # output is float even if one operand is a float
# Out:
# 5.0

# %%
4.0 + 5.0
# Out:
# 9.0

# %%
4/2 # regular division will always output float
# Out:
# 2.0

# %%
4.0/2
# Out:
# 2.0

# %%
5//2 ###. floor division
# Out:
# 2

# %%
-5//2
# Out:
# -3

# %%
9%2
# Out:
# 1

# %%
9.0%2
# Out:
# 1.0

# %%
9* 3
# Out:
# 27

# %%
'a'* 'b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_578/4076593137.py in <cell line: 0>()
# ----> 1 'a'* 'b'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
'a' * 3 ## integer with string
# Out:
# 'aaa'

# %%
"saneeta" > "Harini" ### lexicofraphical order
# Out:
# True

# %%
'x' > 'X'
# Out:
# True

# %%
90>22
# Out:
# True

# %%
a = 10 b = 20
# Out:
#   File "/tmp/ipykernel_578/2810073871.py", line 1
#     a = 10 b = 20
#            ^
# SyntaxError: invalid syntax

# %%
print(" saneeta ")
# Out:
#  saneeta

# %%
Print("saneeta")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_578/2960117250.py in <cell line: 0>()
# ----> 1 Print("saneeta")
#
# NameError: name 'Print' is not defined

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65
