# %% [markdown]
# <a href="https://colab.research.google.com/github/codebuzznow-coder/Python_class1/blob/main/Loops_03%7C11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# print numbers 1 to 10. using while.

# %%
start = 0
end = 10
while start < 10:
  start += 1
  print("value is", start) # variable and not a string
# Out:
# value is 1
# value is 2
# value is 3
# value is 4
# value is 5
# value is 6
# value is 7
# value is 8
# value is 9
# value is 10

# %%
# Take start and end values from users and only print even numbers using while loop.

start = int(input())
end = int(input())
if start%2==1: ##Filter this is false it is odd
  start = start+1 # will always be even
  #print(start)
while start < end:
  print(start)
  start += 2
#print(start)
# Out:
# 5
# 10
# 6
# 8

# %%
3,4,5,6,7,8,9,10

# %%
i = 1
while i < 10:
  print(i)
  i = i + 2
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
i = 2
while i < 10:
  print(i, end = ",")
  i = i + 2
# Out:
# 2,4,6,8,
