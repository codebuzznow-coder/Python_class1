# %% [markdown]
# <a href="https://colab.research.google.com/github/codebuzznow-coder/Python_class1/blob/main/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to python")
# Out:
# welcome to python

# %% [markdown]
# welcome to the class

# %%
a = "Saneeta"
print(a)
# Out:
# Saneeta

# %%
a = "mounika" #method print()
print(a)
# Out:
# mounika

# %%
##inbuit method called type()

type(a)
# Out:
# str

# %%
b = 5.5
type(b)
# Out:
# float

# %%
type(1) ### in python 0 it is false and when it is 1 = true
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type("13444")
# Out:
# str

# %%
enter_name = input() # method. this information to be provided by the user
# Out:
# mounika

# %%
name = input("enter your name")+"@gmail.com"
print(name)
# Out:
# enter your namemounika
# mounika@gmail.com
